# %%
import os
os.chdir('..')
from pathlib import Path
from phc_mjx.smpllib.smpl_local_robot import SMPL_Robot
import numpy as np
import mujoco
import PIL.Image
from omegaconf import OmegaConf
from phc_mjx.envs.humanoid_env import HumanoidEnv
import mediapy as media


YAML_CONFIG_STR = """
control:
    power_scale: 1
    control_mode: "uhc_pd"
    kp_scale: 1.0
    kd_scale: 1.0
    pdp_scale: 1
    pdd_scale: 1
    pdi_scale: 1
env:
    task: HumanoidEnv
    note: this is the default config file for humanoid_env
    motion_file: ""
    model_file: ""
    episode_length: 300
    sim_timestep_inv: 450
    control_frequency_inv: 15
    control_mode: "uhc_pd"
    power_scale: 1.0
    root_height_obs: true
    enable_early_termination: True
    self_obs_v: 1
    kp_scale: 1.0
    kd_scale: 1.0
    cycle_motion: False
    power_reward: True
    clip_actions: True
    contact_bodies: ["R_Ankle", "L_Ankle", "R_Toe", "L_Toe"]
    render_mode: "rgb_array"
    camera: "side"
    state_init: Default
    pdp_scale: 1
    pdd_scale: 1
    pdi_scale: 1
robot:
    note: "Humanoid robot with SMPL body model."
    humanoid_type: smpl
    has_upright_start: False
    has_shape_obs: False
    has_weight_obs: False
    has_shape_variation: False
    has_mesh: False
    replace_feet: True
    has_jt_limit: False
    height_fix_mode: full
    big_ankle: True
    remove_toe: False
    real_weight_porpotion_capsules: True
    real_weight_porpotion_boxes: True
    real_weight: True
    box_body: True
    create_vel_sensors: True
    contact_bodies: ["R_Ankle", "L_Ankle", "R_Toe", "L_Toe"]
    smpl_data_dir: /Users/matthew/projects/PHC_MJX/data/smpl
    use_smpl_data: True
    
headless: False
"""
cfg = OmegaConf.create(YAML_CONFIG_STR)
env = HumanoidEnv(cfg)
obs, info = env.reset(seed=0)

# robot_cfg = {
#     "mesh": cfg.robot.has_mesh,
#     "replace_feet": cfg.robot.replace_feet,
#     "rel_joint_lm": cfg.robot.has_jt_limit,
#     "remove_toe": cfg.robot.get("remove_toe", False),
#     "freeze_hand": cfg.robot.get("freeze_hand", False),
#     "real_weight_porpotion_capsules": cfg.robot.real_weight_porpotion_capsules,
#     "real_weight_porpotion_boxes": cfg.robot.real_weight_porpotion_boxes,
#     "real_weight": cfg.robot.real_weight,
#     "master_range": cfg.robot.get("master_range", 30),
#     "big_ankle": cfg.robot.big_ankle,
#     "box_body": cfg.robot.box_body,
#     "masterfoot": cfg.robot.get("masterfoot", False),
#     "upright_start": cfg.robot.has_upright_start,
#     "model": cfg.robot.humanoid_type,
#     "body_params": {},
#     "joint_params": {},
#     "geom_params": {},
#     "actuator_params": {},
# }
# robot = SMPL_Robot(
#     robot_cfg,
#     data_dir=cfg.robot.smpl_data_dir,
# )

# xml = robot.export_xml_string().decode("utf-8")
# mj_model = mujoco.MjModel.from_xml_string(xml)
# mj_data = mujoco.MjData(mj_model)
# Out:
# /Users/matthew/projects
# /Users/matthew/projects/PHC_MJX/data/smpl

# %%
mj_data = env.mj_data
mj_model = env.mj_model

mj_data.qpos[:] = 0
mj_data.qvel[:] = 0
mj_data.qpos[2] = 0.94
mj_data.qpos[3:7] = np.array([0.5, 0.5, 0.5, 0.5])


sim_timestep_inv = 450
sim_timestep = 1.0 / sim_timestep_inv
control_frequency_inv = 15
mj_model.opt.timestep = sim_timestep

# setup renderer
mj_renderer = mujoco.Renderer(mj_model)
mujoco.mj_forward(mj_model, mj_data)
cam = mujoco.MjvCamera()
mujoco.mjv_defaultCamera(cam)
cam.distance, cam.azimuth, cam.elevation, cam.lookat = 3, 0, -20, mj_data.qpos[:3]
mj_renderer.update_scene(mj_data, cam)
pixels = mj_renderer.render()
PIL.Image.fromarray(pixels)


# _smpl_robot_info = {
#     "height": _smpl_robot.height.item(),
#     "gender": gender,
#     "weight": mujoco.mj_getTotalmass(mj_model),
#     "beta": beta.ravel()
# }

# for k, v in _smpl_robot_info.items():
#     print(f"{k}: {v}")
# Out:
# <PIL.Image.Image image mode=RGB size=320x240>

# %%
frames = [mj_renderer.render()]
num_steps = 10
print(mj_model.opt.timestep)
mj_model.opt.integrator = mujoco.mjtIntegrator.mjINT_RK4
for time in range(num_steps):
    action = np.random.rand(env.action_space.shape[0]) * 2 - 1
    torque = env.power_scale * env.torque_lim * action
    print(torque.min(), torque.max())
    for internal_step in range(control_frequency_inv):
        mj_data.ctrl[:] = torque
        mujoco.mj_step(mj_model, mj_data)
        if mj_data.warning.number.any():
            warning_index = np.nonzero(mj_data.warning.number)[0].item()
            print(warning_index)
            warning = mujoco.mjtWarning(warning_index).name
            print(f'stopped due to divergence ({warning}) at timestep {time}/{internal_step}.\n')

            # mj_data.qpos[:] = 0
            # mj_data.qvel[:] = 0
            # mj_data.qpos[2] = 0.94
            # mj_data.qpos[3:7] = np.array([0.5, 0.5, 0.5, 0.5])
            # mujoco.mj_forward(mj_model, mj_data)

            # break
    cam.lookat = mj_data.qpos[:3]
    mj_renderer.update_scene(mj_data, cam)
    pixels = mj_renderer.render()
    frames.append(pixels)

media.show_video(frames, fps=5)
# Out:
# 0.0022222222222222222
# -795.4577429086196 919.5392818321924
# -973.0902059642669 947.5164330531937
# -958.9914711854864 957.3955054452732
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/1.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/2.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/3.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/4.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/5.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/6.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/7.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/8.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/9.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/10.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/11.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/12.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/13.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 2/14.
#
# -970.3827284482813 822.2691107053246
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 3/0.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 3/1.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 3/2.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 3/3.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 3/4.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 3/5.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 3/6.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 3/7.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 3/8.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 3/9.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 3/10.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 3/11.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 3/12.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 3/13.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 3/14.
#
# -999.3763078211349 922.3059151112208
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/0.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/1.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/2.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/3.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/4.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/5.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/6.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/7.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/8.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/9.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/10.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/11.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/12.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/13.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 4/14.
#
# -861.2477417842224 985.0462437134693
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/0.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/1.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/2.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/3.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/4.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/5.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/6.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/7.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/8.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/9.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/10.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/11.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/12.
#
# 4
# stopped due to divergence (mjWARN_BADQPOS) at timestep 5/13.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 5/14.
#
# -917.6460523694112 995.4426352402106
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/0.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/1.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/2.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/3.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/4.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/5.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/6.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/7.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/8.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/9.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/10.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/11.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/12.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/13.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 6/14.
#
# -948.5100088544376 923.8027023602813
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 7/0.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/1.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/2.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/3.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/4.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/5.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/6.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/7.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/8.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/9.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/10.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/11.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/12.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/13.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 7/14.
#
# -909.653895903745 984.7456671023845
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 8/0.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 8/1.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 8/2.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 8/3.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 8/4.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 8/5.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 8/6.
#
# 6
# stopped due to divergence (mjWARN_BADQACC) at timestep 8/7.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 8/8.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 8/9.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 8/10.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 8/11.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 8/12.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 8/13.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 8/14.
#
# -994.0804940454169 776.0571977526831
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/0.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/1.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/2.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/3.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/4.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/5.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/6.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/7.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/8.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/9.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/10.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/11.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/12.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/13.
#
# 5
# stopped due to divergence (mjWARN_BADQVEL) at timestep 9/14.
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
